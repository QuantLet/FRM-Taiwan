# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import matplotlib.dates as mdates
import matplotlib.path as mpath
import yfinance as yf

# %% [markdown]
# ## Full Image

# %%
df = pd.read_csv('covid-19.csv')
start_date = '2020-01-01'
end_date = '2023-03-10'

df['Date'] = pd.to_datetime(df['Date'])
mask = (df['Date'] >= pd.Timestamp(start_date)) & (df['Date'] <= pd.Timestamp(end_date))
df = df.loc[mask]

df['Taiwan_Daily'] = df['Taiwan_Accumulate'].diff().fillna(0)

plt.figure(figsize=(15, 6))
plt.bar(df['Date'], df['Taiwan_Accumulate'], color='royalblue', width=0.3)
plt.ylim(0,)
plt.xticks(fontsize=14, fontweight='bold')
plt.yticks(fontsize=14, fontweight='bold')
plt.ylabel("Total Confirmed Cases", fontsize=14, fontweight='bold')
plt.gca().get_yaxis().get_major_formatter().set_scientific(False)
plt.show()

plt.figure(figsize=(15, 6))
plt.plot(df['Date'], df['Taiwan_Daily'], color='royalblue')
plt.ylim(0,)
plt.xticks(fontsize=14, fontweight='bold')
plt.yticks(fontsize=14, fontweight='bold')
plt.ylabel("Daily Confirmed Cases", fontsize=14, fontweight='bold')
plt.show()


plt.figure(figsize=(15, 6))

ax1 = plt.gca()
ax2 = ax1.twinx()

ax1.plot(df['Date'], df['Taiwan_Daily'], color='salmon', label='Total Confirmed Cases', linewidth=4)
ax1.set_ylim(0, )
ax1.set_ylabel("Daily Confirmed Cases", fontsize=18, fontweight='bold', color='salmon')
ax1.tick_params(axis='y', labelcolor='salmon', labelsize=18, width=2)
ax1.yaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{int(x):,}'))
ax1.xaxis.set_major_locator(mdates.DayLocator(interval=180))
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
ax1.set_yticklabels([f'{int(x):,}' for x in ax1.get_yticks()], size=14, weight='bold')

ax2.bar(df['Date'], df['Taiwan_Accumulate'], color='royalblue', label='Daily Confirmed Cases', linewidth=4, width=0.3)
ax2.yaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{int(x):,}'))
ax2.set_ylabel("Total Confirmed Cases", fontsize=16, fontweight='bold', color='royalblue')
ax2.tick_params(axis='y', labelcolor='royalblue', labelsize=18, width=2)
ax2.set_yticklabels([f'{int(x):,}' for x in ax2.get_yticks()], size=14, weight='bold')

plt.draw()

ax1.set_xticklabels([x.get_text() for x in ax1.get_xticklabels()], size=14, weight='bold')

plt.tight_layout()
plt.savefig('Events/Total_Covid.png', dpi=144, transparent=True)
plt.show()
# Out:
# /var/folders/0j/0cgjnq7x6_xgggqt92c7300r0000gn/T/ipykernel_10046/1425507347.py:41: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_yticklabels([f'{int(x):,}' for x in ax1.get_yticks()], size=14, weight='bold')
# /var/folders/0j/0cgjnq7x6_xgggqt92c7300r0000gn/T/ipykernel_10046/1425507347.py:47: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_yticklabels([f'{int(x):,}' for x in ax2.get_yticks()], size=14, weight='bold')
# /var/folders/0j/0cgjnq7x6_xgggqt92c7300r0000gn/T/ipykernel_10046/1425507347.py:51: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels([x.get_text() for x in ax1.get_xticklabels()], size=14, weight='bold')

# %% [markdown]
# ## First Covid

# %%
df = pd.read_csv('covid-19.csv')
start_date = '2020-01-01'
end_date = '2020-06-30'
start_period = '2020-01-30'
end_period = '2020-05-10'

df['Date'] = pd.to_datetime(df['Date'])
mask = (df['Date'] >= pd.Timestamp(start_date)) & (df['Date'] <= pd.Timestamp(end_date))
df = df.loc[mask]

df['Taiwan_Daily'] = df['Taiwan_Accumulate'].diff().fillna(0)

Index = yf.download('^TWII', start=start_date, end=end_date)
Index.index.name = None
Index['Date'] = Index.index

plt.figure(figsize=(15, 6))
plt.bar(df['Date'], df['Taiwan_Accumulate'], color='royalblue', width=0.3)
plt.ylim(0, )
plt.xticks(fontsize=14, fontweight='bold')
plt.yticks(fontsize=14, fontweight='bold')
plt.ylabel("Total Confirmed Cases", fontsize=14, fontweight='bold')
plt.show()

#####

plt.figure(figsize=(15, 6))
plt.plot(df['Date'], df['Taiwan_Daily'], color='royalblue')
plt.ylim(0, )
plt.xticks(fontsize=14, fontweight='bold')
plt.yticks(fontsize=14, fontweight='bold')
plt.ylabel("Daily Confirmed Cases", fontsize=14, fontweight='bold')
plt.show()

#####

plt.figure(figsize=(15, 6))

ax1 = plt.gca()
ax2 = ax1.twinx()

ax1.plot(df['Date'], df['Taiwan_Daily'], color='salmon', label='Total Confirmed Cases', linewidth=4)
ax1.set_ylim(0, )
ax1.set_ylabel("Daily Confirmed Cases", fontsize=18, fontweight='bold', color='salmon')
ax1.tick_params(axis='y', labelcolor='salmon', labelsize=18, width=2)
ax1.yaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{int(x):,}'))
ax1.xaxis.set_major_locator(mdates.DayLocator(interval=30))
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
ax1.set_yticklabels([f'{int(x):,}' for x in ax1.get_yticks()], size=14, weight='bold')

ax2.bar(df['Date'], df['Taiwan_Accumulate'], color='royalblue', label='Daily Confirmed Cases', linewidth=4, width=0.3)
ax2.yaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{int(x):,}'))
ax2.set_ylabel("Total Confirmed Cases", fontsize=16, fontweight='bold', color='royalblue')
ax2.tick_params(axis='y', labelcolor='royalblue', labelsize=18, width=2)
ax2.set_yticklabels([f'{int(x):,}' for x in ax2.get_yticks()], size=14, weight='bold')

plt.draw()

ax1.set_xticklabels([x.get_text() for x in ax1.get_xticklabels()], size=14, weight='bold')

plt.tight_layout()
plt.show()

#####

fig, (ax1, ax3) = plt.subplots(2, 1, figsize=(15, 8), gridspec_kw={'height_ratios': [1, 1]}, sharex=True)

ax2 = ax1.twinx()
ax1.plot(df['Date'], df['Taiwan_Daily'], color='salmon', label='Total Confirmed Cases', linewidth=4)
ax1.set_ylim(0, )
ax1.set_ylabel("Daily Confirmed Cases", fontsize=18, fontweight='bold', color='salmon')
ax1.set_yticklabels([f'{int(x):,}' for x in ax1.get_yticks()], size=14, weight='bold', color='salmon')
ax1.yaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{int(x):,}'))
ax1.xaxis.set_major_locator(mdates.DayLocator(interval=30))
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

ax2.bar(df['Date'], df['Taiwan_Accumulate'], color='royalblue', label='Daily Confirmed Cases', linewidth=4, width=0.3)
ax2.set_ylabel("Total Confirmed Cases", fontsize=16, fontweight='bold', color='royalblue')
ax2.yaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{int(x):,}'))
ax2.set_yticklabels([f'{int(x):,}' for x in ax2.get_yticks()], size=14, weight='bold', color='royalblue')

ax3.plot(Index['Date'], Index['Close'], color='black', label='TWSE Index', linewidth=2)
ax3.set_ylabel("TAIEX", fontsize=18, fontweight='bold', color='black')
ax3.xaxis.set_major_locator(mdates.DayLocator(interval=30))
ax3.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
ax3.set_yticklabels([f'{int(x):,}' for x in ax3.get_yticks()], size=14, weight='bold', color='black')
ax3.set_xticklabels([x.get_text() for x in ax3.get_xticklabels()], size=14, weight='bold')

for ax in [ax1, ax3]:
    ax.axvspan(pd.Timestamp(start_period), pd.Timestamp(end_period), color='grey', alpha=0.3)


plt.tight_layout()
plt.savefig('Events/First_Covid.png', dpi=144, transparent=True)
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# /var/folders/0j/0cgjnq7x6_xgggqt92c7300r0000gn/T/ipykernel_13966/2958432242.py:49: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_yticklabels([f'{int(x):,}' for x in ax1.get_yticks()], size=14, weight='bold')
# /var/folders/0j/0cgjnq7x6_xgggqt92c7300r0000gn/T/ipykernel_13966/2958432242.py:55: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_yticklabels([f'{int(x):,}' for x in ax2.get_yticks()], size=14, weight='bold')
# /var/folders/0j/0cgjnq7x6_xgggqt92c7300r0000gn/T/ipykernel_13966/2958432242.py:59: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels([x.get_text() for x in ax1.get_xticklabels()], size=14, weight='bold')
# ...

# %% [markdown]
# ## Second Covid

# %%
df = pd.read_csv('covid-19.csv')
start_date = '2021-04-01'
end_date = '2021-09-30'
start_period = '2021-05-01'
end_period = '2021-07-27'

df['Date'] = pd.to_datetime(df['Date'])
mask = (df['Date'] >= pd.Timestamp(start_date)) & (df['Date'] <= pd.Timestamp(end_date))
df = df.loc[mask]

df['Taiwan_Daily'] = df['Taiwan_Accumulate'].diff().fillna(0)

Index = yf.download('^TWII', start=start_date, end=end_date)
Index.index.name = None
Index['Date'] = Index.index

plt.figure(figsize=(15, 6))
plt.bar(df['Date'], df['Taiwan_Accumulate'], color='royalblue', width=0.3)
plt.ylim(0 )
plt.xticks(fontsize=14, fontweight='bold')
plt.yticks(fontsize=14, fontweight='bold')
plt.ylabel("Total Confirmed Cases", fontsize=14, fontweight='bold')
plt.show()

#####

plt.figure(figsize=(15, 6))
plt.plot(df['Date'], df['Taiwan_Daily'], color='royalblue')
plt.ylim(0, )
plt.xticks(fontsize=14, fontweight='bold')
plt.yticks(fontsize=14, fontweight='bold')
plt.ylabel("Daily Confirmed Cases", fontsize=14, fontweight='bold')
plt.show()

#####

plt.figure(figsize=(15, 6))

ax1 = plt.gca()
ax2 = ax1.twinx()

ax1.plot(df['Date'], df['Taiwan_Daily'], color='salmon', label='Total Confirmed Cases', linewidth=4)
ax1.set_ylim(0, )
ax1.set_ylabel("Daily Confirmed Cases", fontsize=18, fontweight='bold', color='salmon')
ax1.tick_params(axis='y', labelcolor='salmon', labelsize=18, width=2)
ax1.yaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{int(x):,}'))
ax1.xaxis.set_major_locator(mdates.DayLocator(interval=30))
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
ax1.set_yticklabels([f'{int(x):,}' for x in ax1.get_yticks()], size=14, weight='bold')

ax2.bar(df['Date'], df['Taiwan_Accumulate'], color='royalblue', label='Daily Confirmed Cases', linewidth=4, width=0.3)
ax2.yaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{int(x):,}'))
ax2.set_ylabel("Total Confirmed Cases", fontsize=16, fontweight='bold', color='royalblue')
ax2.tick_params(axis='y', labelcolor='royalblue', labelsize=18, width=2)
ax2.set_yticklabels([f'{int(x):,}' for x in ax2.get_yticks()], size=14, weight='bold')

plt.draw()

ax1.set_xticklabels([x.get_text() for x in ax1.get_xticklabels()], size=14, weight='bold')

plt.tight_layout()
plt.show()

#####

fig, (ax1, ax3) = plt.subplots(2, 1, figsize=(15, 8), gridspec_kw={'height_ratios': [1, 1]}, sharex=True)

ax2 = ax1.twinx()
ax1.plot(df['Date'], df['Taiwan_Daily'], color='salmon', label='Total Confirmed Cases', linewidth=4)
ax1.set_ylim(0, )
ax1.set_ylabel("Daily Confirmed Cases", fontsize=18, fontweight='bold', color='salmon')
ax1.set_yticklabels([f'{int(x):,}' for x in ax1.get_yticks()], size=14, weight='bold', color='salmon')
ax1.yaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{int(x):,}'))
ax1.xaxis.set_major_locator(mdates.DayLocator(interval=30))
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

ax2.bar(df['Date'], df['Taiwan_Accumulate'], color='royalblue', label='Daily Confirmed Cases', linewidth=4, width=0.3)
ax2.set_ylabel("Total Confirmed Cases", fontsize=16, fontweight='bold', color='royalblue')
ax2.yaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{int(x):,}'))
ax2.set_yticklabels([f'{int(x):,}' for x in ax2.get_yticks()], size=14, weight='bold', color='royalblue')

ax3.plot(Index['Date'], Index['Close'], color='black', label='TWSE Index', linewidth=2)
ax3.set_ylabel("TAIEX", fontsize=18, fontweight='bold', color='black')
ax3.xaxis.set_major_locator(mdates.DayLocator(interval=30))
ax3.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
ax3.set_yticklabels([f'{int(x):,}' for x in ax3.get_yticks()], size=14, weight='bold', color='black')
ax3.set_xticklabels([x.get_text() for x in ax3.get_xticklabels()], size=14, weight='bold')

for ax in [ax1, ax3]:
    ax.axvspan(pd.Timestamp(start_period), pd.Timestamp(end_period), color='grey', alpha=0.3)


plt.tight_layout()
plt.savefig('Events/Second_Covid.png', dpi=144, transparent=True)
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# /var/folders/0j/0cgjnq7x6_xgggqt92c7300r0000gn/T/ipykernel_13966/407767210.py:49: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_yticklabels([f'{int(x):,}' for x in ax1.get_yticks()], size=14, weight='bold')
# /var/folders/0j/0cgjnq7x6_xgggqt92c7300r0000gn/T/ipykernel_13966/407767210.py:55: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_yticklabels([f'{int(x):,}' for x in ax2.get_yticks()], size=14, weight='bold')
# /var/folders/0j/0cgjnq7x6_xgggqt92c7300r0000gn/T/ipykernel_13966/407767210.py:59: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels([x.get_text() for x in ax1.get_xticklabels()], size=14, weight='bold')
# ...

# %% [markdown]
# ## Third Covid

# %%
df = pd.read_csv('covid-19.csv')
start_date = '2022-03-01'
end_date = '2023-02-28'
start_period = '2022-03-01'
end_period = '2023-02-28'

df['Date'] = pd.to_datetime(df['Date'])
mask = (df['Date'] >= pd.Timestamp(start_date)) & (df['Date'] <= pd.Timestamp(end_date))
df = df.loc[mask]

df['Taiwan_Daily'] = df['Taiwan_Accumulate'].diff().fillna(0)

Index = yf.download('^TWII', start=start_date, end=end_date)
Index.index.name = None
Index['Date'] = Index.index

plt.figure(figsize=(15, 6))
plt.bar(df['Date'], df['Taiwan_Accumulate'], color='royalblue', width=0.3)
plt.ylim(0 )
plt.xticks(fontsize=14, fontweight='bold')
plt.yticks(fontsize=14, fontweight='bold')
plt.ylabel("Total Confirmed Cases", fontsize=14, fontweight='bold')
plt.show()

#####

plt.figure(figsize=(15, 6))
plt.plot(df['Date'], df['Taiwan_Daily'], color='royalblue')
plt.ylim(0, )
plt.xticks(fontsize=14, fontweight='bold')
plt.yticks(fontsize=14, fontweight='bold')
plt.ylabel("Daily Confirmed Cases", fontsize=14, fontweight='bold')
plt.show()

#####

plt.figure(figsize=(15, 6))

ax1 = plt.gca()
ax2 = ax1.twinx()

ax1.plot(df['Date'], df['Taiwan_Daily'], color='salmon', label='Total Confirmed Cases', linewidth=4)
ax1.set_ylim(0, )
ax1.set_ylabel("Daily Confirmed Cases", fontsize=18, fontweight='bold', color='salmon')
ax1.tick_params(axis='y', labelcolor='salmon', labelsize=18, width=2)
ax1.yaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{int(x):,}'))
ax1.xaxis.set_major_locator(mdates.DayLocator(interval=30))
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
ax1.set_yticklabels([f'{int(x):,}' for x in ax1.get_yticks()], size=14, weight='bold')

ax2.bar(df['Date'], df['Taiwan_Accumulate'], color='royalblue', label='Daily Confirmed Cases', linewidth=4, width=0.3)
ax2.yaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{int(x):,}'))
ax2.set_ylabel("Total Confirmed Cases", fontsize=16, fontweight='bold', color='royalblue')
ax2.tick_params(axis='y', labelcolor='royalblue', labelsize=18, width=2)
ax2.set_yticklabels([f'{int(x):,}' for x in ax2.get_yticks()], size=14, weight='bold')

plt.draw()

ax1.set_xticklabels([x.get_text() for x in ax1.get_xticklabels()], size=14, weight='bold')

plt.tight_layout()
plt.show()

#####

fig, (ax1, ax3) = plt.subplots(2, 1, figsize=(15, 8), gridspec_kw={'height_ratios': [1, 1]}, sharex=True)

ax2 = ax1.twinx()
ax1.plot(df['Date'], df['Taiwan_Daily'], color='salmon', label='Total Confirmed Cases', linewidth=4)
ax1.set_ylim(0, )
ax1.set_ylabel("Daily Confirmed Cases", fontsize=18, fontweight='bold', color='salmon')
ax1.set_yticklabels([f'{int(x):,}' for x in ax1.get_yticks()], size=14, weight='bold', color='salmon')
ax1.yaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{int(x):,}'))
ax1.xaxis.set_major_locator(mdates.DayLocator(interval=30))
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

ax2.bar(df['Date'], df['Taiwan_Accumulate'], color='royalblue', label='Daily Confirmed Cases', linewidth=4, width=0.3)
ax2.set_ylabel("Total Confirmed Cases", fontsize=16, fontweight='bold', color='royalblue')
ax2.yaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{int(x):,}'))
ax2.set_yticklabels([f'{int(x):,}' for x in ax2.get_yticks()], size=14, weight='bold', color='royalblue')

ax3.plot(Index['Date'], Index['Close'], color='black', label='TWSE Index', linewidth=2)
ax3.set_ylabel("TAIEX", fontsize=18, fontweight='bold', color='black')
ax3.xaxis.set_major_locator(mdates.DayLocator(interval=30))
ax3.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
ax3.set_yticklabels([f'{int(x):,}' for x in ax3.get_yticks()], size=14, weight='bold', color='black')
ax3.set_xticklabels([x.get_text() for x in ax3.get_xticklabels()], size=14, weight='bold')

for ax in [ax1, ax3]:
    ax.axvspan(pd.Timestamp(start_period), pd.Timestamp(end_period), color='grey', alpha=0.3)


plt.tight_layout()
plt.savefig('Events/Last_Covid.png', dpi=144, transparent=True)
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# /var/folders/0j/0cgjnq7x6_xgggqt92c7300r0000gn/T/ipykernel_13966/2669419152.py:49: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_yticklabels([f'{int(x):,}' for x in ax1.get_yticks()], size=14, weight='bold')
# /var/folders/0j/0cgjnq7x6_xgggqt92c7300r0000gn/T/ipykernel_13966/2669419152.py:55: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_yticklabels([f'{int(x):,}' for x in ax2.get_yticks()], size=14, weight='bold')
# /var/folders/0j/0cgjnq7x6_xgggqt92c7300r0000gn/T/ipykernel_13966/2669419152.py:59: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels([x.get_text() for x in ax1.get_xticklabels()], size=14, weight='bold')
# ...

# %%
start_date = '2021-10-01'
end_date = '2023-07-31'
start_period = '2022-02-24'
end_period = '2023-07-31'
war = '2022-02-24'

df = pd.read_csv('FEDFUNDS.csv')
df['Date'] = pd.to_datetime(df['Date'])
df = df.set_index('Date').resample('D').ffill().reset_index()

df['Date'] = pd.to_datetime(df['Date'])
mask = (df['Date'] >= pd.Timestamp(start_date)) & (df['Date'] <= pd.Timestamp(end_date))
df = df.loc[mask]

Index = yf.download('^TWII', start=start_date, end=end_date)
Index['Date'] = Index.index

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(15, 8), gridspec_kw={'height_ratios': [1, 1]}, sharex=True)

ax1.plot(df['Date'], df['FEDFUNDS'], color='salmon', label='Federal Funds Rate', linewidth=4)
ax1.set_ylabel("Federal Funds Rate", fontsize=18, fontweight='bold', color='salmon')
ax1.yaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{x}%'))
ax1.xaxis.set_major_locator(mdates.MonthLocator(bymonth=(1, 7)))
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
ax1.set_yticklabels([f'{x}%' for x in ax1.get_yticks()], size=14, weight='bold', color='salmon')

ax2.plot(Index['Date'], Index['Close'], color='black', label='TWSE Index', linewidth=2)
ax2.set_ylabel("TAIEX", fontsize=18, fontweight='bold', color='black')
ax2.yaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{int(x):,}'))
ax2.xaxis.set_major_locator(mdates.MonthLocator(bymonth=(1, 7)))
ax2.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
ax2.set_yticklabels([f'{int(x):,}' for x in ax2.get_yticks()], size=14, weight='bold', color='black')
ax2.set_xticklabels([x.get_text() for x in ax2.get_xticklabels()], size=14, weight='bold')

for ax in [ax1, ax2]:
    ax.axvspan(pd.Timestamp(start_period), pd.Timestamp(end_period), color='grey', alpha=0.3)
    ax.axvline(pd.Timestamp(war), color='royalblue', linestyle='--', linewidth=5)

events = {
    '2022-02-24': "Russo-Ukrainian War",
}

for ax in [ax1]:
    for event_date, event_name in events.items():
        ax.text(pd.to_datetime(event_date), ax.get_ylim()[1], event_name, rotation=0, verticalalignment='bottom', horizontalalignment='left', color='royalblue', fontsize=20, fontweight='bold')

plt.tight_layout()
plt.savefig('Events/FedFunds_Raise.png', dpi=144, transparent=True)
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# /var/folders/0j/0cgjnq7x6_xgggqt92c7300r0000gn/T/ipykernel_13966/1724908505.py:25: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_yticklabels([f'{x}%' for x in ax1.get_yticks()], size=14, weight='bold', color='salmon')
# /var/folders/0j/0cgjnq7x6_xgggqt92c7300r0000gn/T/ipykernel_13966/1724908505.py:32: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_yticklabels([f'{int(x):,}' for x in ax2.get_yticks()], size=14, weight='bold', color='black')
# /var/folders/0j/0cgjnq7x6_xgggqt92c7300r0000gn/T/ipykernel_13966/1724908505.py:33: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
# ...

# %% [markdown]
# ## 2023.03.09 Full Image

# %%
df = pd.read_csv('covid-19.csv')
FRM = pd.read_csv('../02 Modeling/50elefin_63/lambdas.csv', index_col='time')
FRM.index.name = None
FRM.index = pd.to_datetime(FRM.index)

start_date = pd.to_datetime(FRM.index)[0].strftime('%Y-%m-%d')
end_date = pd.to_datetime(FRM.index)[-1].strftime('%Y-%m-%d')


df['Date'] = pd.to_datetime(df['Date'])
mask = (df['Date'] >= pd.Timestamp(start_date)) & (df['Date'] <= pd.Timestamp(end_date))
df = df.loc[mask]

df['Taiwan_Daily'] = df['Taiwan_Accumulate'].diff().fillna(0)
df.index = df['Date']
df.index.name = None

FED_M = pd.read_csv('FEDFUNDS.csv', index_col='Date')
FED_M.index = pd.to_datetime(FED_M.index)
FED_M.index.name = None
FED = FED_M.resample('D').ffill()

mask = (FED.index >= pd.Timestamp(start_date)) & (FED.index <= pd.Timestamp(end_date))
FED = FED.loc[mask]

mask_M = (FED_M.index >= pd.Timestamp(start_date)) & (FED_M.index <= pd.Timestamp(end_date))
FED_M = FED_M.loc[mask_M]

Index = yf.download('^TWII', start=start_date, end=end_date)
Index.index.name = None
Index['Date'] = Index.index

BCI = pd.read_csv('../00 Raw Data/Indicator.csv', index_col=0, parse_dates=True).rename_axis(None, axis=0)
BCI.index = BCI.index + pd.offsets.MonthEnd(0)
BCI.columns = ['BCI']
BCI = BCI.loc[FRM.resample('M').last().index]

fig, (ax3, ax1, ax4, ax5) = plt.subplots(4, 1, figsize=(15, 12), gridspec_kw={'height_ratios': [1, 1, 1, 1]}, sharex=True)

ax2 = ax1.twinx()
ax1.plot(df['Date'], np.log10(df['Taiwan_Daily']+1), color='salmon', label='Total Confirmed Cases', linewidth=1.2)
ax1.set_ylim(0, )
ax1.set_ylabel("Daily Confirmed Cases", fontsize=14, fontweight='bold', color='salmon')
ax1.set_yticklabels([f'{int(x):,}' for x in ax1.get_yticks()], size=14, weight='bold', color='salmon')
# ax1.yaxis.set_major_formatter(FuncFormatter(lambda y, _: f'{np.log(y):,.0f}'))
ax1.yaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{int(x):,}'))

ax1.xaxis.set_major_locator(mdates.DayLocator(interval=30))
ax1.xaxis.set_major_locator(mdates.MonthLocator(bymonth=(1, 7)))
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

ax2.bar(df['Date'], np.log10(df['Taiwan_Accumulate']+1), color='royalblue', label='Daily Confirmed Cases', linewidth=0.6, width=0.2)
ax2.set_ylabel("Total Confirmed Cases", fontsize=14, fontweight='bold', color='royalblue')
ax2.yaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{int(x):,}'))
ax2.set_yticklabels([f'{int(x):,}' for x in ax2.get_yticks()], size=14, weight='bold', color='royalblue')

actual_yticks_daily = [1, 10, 100, 1000, 10000, 100000]
actual_yticks_total = [1, 10, 100, 1000, 10000, 100000, 1000000, 10000000]
log_yticks_daily = np.log10(actual_yticks_daily)
log_yticks_total = np.log10(actual_yticks_total)
ax1.set_yticks(log_yticks_daily)
ax2.set_yticks(log_yticks_total)
formatter = FuncFormatter(lambda y, _: f'{10**y:,.0f}')
ax1.yaxis.set_major_formatter(formatter)
ax2.yaxis.set_major_formatter(formatter)
ax1.set_yticklabels([f'{int(x):,}' for x in actual_yticks_daily], size=14, weight='bold', color='salmon')
ax2.set_yticklabels([f'{int(x):,}' for x in actual_yticks_total], size=14, weight='bold', color='royalblue')


ax3.plot(Index['Date'], Index['Adj Close'], color='black', label='TWSE Index', linewidth=2)
ax3.set_ylabel("TAIEX", fontsize=14, fontweight='bold', color='black')
ax3.xaxis.set_major_locator(mdates.DayLocator(interval=30))
ax3.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
ax3.set_yticklabels([f'{int(x):,}' for x in ax3.get_yticks()], size=14, weight='bold', color='black')
ax3.set_xticklabels([x.get_text() for x in ax3.get_xticklabels()], size=14, weight='bold')

ax4.scatter(FED_M.index, FED_M, color='k')
ax4.plot(FED.index, FED, color='royalblue', linewidth=3, label='FRM')
ax4.set_ylabel("Federal Funds Rate", fontsize=14, fontweight='bold')
ax4.set_yticklabels([f'{x}' for x in ax4.get_yticks()], size=14, weight='bold')
ax4.yaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{x:,.2f}'))
# ax1.yaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{x:,.2f}'))
ax4.xaxis.set_major_locator(mdates.MonthLocator(bymonth=(1, 7)))
ax4.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
ax4.set_xticklabels([x for x in [date.strftime('%Y-%m') for date in [mdates.num2date(x) for x in (ax4.get_xticks())]]], size=14, weight='bold')

for ax in [ax1, ax3, ax4, ax5]:
    start_period = '2020-01-30'
    end_period = '2020-05-10'
    ax.axvspan(pd.Timestamp(start_period), pd.Timestamp(end_period), color='grey', alpha=0.3)

    start_period = '2021-05-01'
    end_period = '2021-07-27'
    ax.axvspan(pd.Timestamp(start_period), pd.Timestamp(end_period), color='grey', alpha=0.3)

    start_period = '2022-02-24'
    end_period = '2023-06-30'
    ax.axvspan(pd.Timestamp(start_period), pd.Timestamp(end_period), color='grey', alpha=0.3)

    start_period = '2022-11-01'
    end_period = '2023-06-30'
    ax.axvspan(pd.Timestamp(start_period), pd.Timestamp(end_period), color='dimgray', alpha=0.3)

#     special_date = '2020-01-16'
#     ax.axvline(pd.Timestamp(special_date), color='darkgreen', linewidth=2, alpha=1)
    
#     special_date = '2020-01-30'
#     ax.axvline(pd.Timestamp(special_date), color='darkgreen', linewidth=2, alpha=1)

#     special_date = '2021-06-25'
#     ax.axvline(pd.Timestamp(special_date), color='darkgreen', linewidth=2, alpha=1)

#     special_date = '2022-08-08'
#     ax.axvline(pd.Timestamp(special_date), color='darkgreen', linewidth=2, alpha=1)

# special_date = '2020-01-16'
# ax3.text(pd.Timestamp(special_date)-pd.Timedelta(days=15), ax3.get_ylim()[1]*0.99, special_date, fontsize=14, color='darkgreen', fontweight='bold', verticalalignment='top', horizontalalignment='right')

# special_date = '2020-01-30'
# ax3.text(pd.Timestamp(special_date)+pd.Timedelta(days=15), ax3.get_ylim()[1]*0.99, special_date, fontsize=14, color='darkgreen', fontweight='bold', verticalalignment='top')

# special_date = '2021-06-25'
# ax3.text(pd.Timestamp(special_date)+pd.Timedelta(days=15), ax3.get_ylim()[1]*0.99, special_date, fontsize=14, color='darkgreen', fontweight='bold', verticalalignment='top')

# special_date = '2022-08-08'
# ax3.text(pd.Timestamp(special_date)+pd.Timedelta(days=15), ax3.get_ylim()[1]*0.99, special_date, fontsize=14, color='darkgreen', fontweight='bold', verticalalignment='top')

ax5.plot(BCI['BCI'], color='gray', linewidth=7, alpha=0.1)
ax5.axhline(y=16.5, color='black', linestyle='-.', linewidth=0.6, alpha=0.4)
ax5.axhline(y=22.5, color='black', linestyle='-.', linewidth=0.6, alpha=0.4)
ax5.axhline(y=31.5, color='black', linestyle='-.', linewidth=0.6, alpha=0.4)
ax5.axhline(y=37.5, color='black', linestyle='-.', linewidth=0.6, alpha=0.4)

def create_semicircle(up=True):
    theta = np.linspace(0, np.pi, 50)  # 生成 50 個點來創建一個平滑的半圓
    x = np.cos(theta)
    y = np.sin(theta) if up else -np.sin(theta)
    verts = np.vstack([x, y]).T
    codes = [mpath.Path.MOVETO] + [mpath.Path.LINETO] * (len(verts) - 2) + [mpath.Path.CLOSEPOLY]
    return mpath.Path(verts, codes)

UpperHalfCircle = create_semicircle(up=True)
LowerHalfCircle = create_semicircle(up=False)

for i in range(len(BCI)):
    val = BCI['BCI'].iloc[i]
    if val < 17:
        ax5.scatter(BCI.index[i], val, color='royalblue', s=60, edgecolors='black', alpha=1)
    elif val < 23:
        ax5.scatter(BCI.index[i], val, color='gold', s=60, edgecolors='black', alpha=1, marker=UpperHalfCircle)
        ax5.scatter(BCI.index[i], val, color='royalblue', s=60, edgecolors='black', alpha=1, marker=LowerHalfCircle)
    elif val < 32:
        ax5.scatter(BCI.index[i], val, color='forestgreen', s=60, edgecolors='black', alpha=1)
    elif val < 38:
        ax5.scatter(BCI.index[i], val, color='red', s=60, edgecolors='black', alpha=1, marker=UpperHalfCircle)
        ax5.scatter(BCI.index[i], val, color='gold', s=60, edgecolors='black', alpha=1, marker=LowerHalfCircle)
    else:
        ax5.scatter(BCI.index[i], val, color='red', s=60, edgecolors='black', alpha=1)
ax5.set_xticklabels([x for x in [date.strftime('%Y-%m') for date in [mdates.num2date(x) for x in (ax5.get_xticks())]]], size=14, weight='bold')
ax5.set_yticklabels([f'{int(x):,}' for x in ax5.get_yticks()], size=14, weight='bold')
ax5.set_ylabel("MI", fontsize=14, fontweight='bold')


# special_dates = ['2020-01-30', '2020-03-19', '2021-05-11', '2022-02-24']
# for special_date in special_dates:
#     df_location = df.index.get_loc(pd.Timestamp(special_date))
#     df_location_value = np.log10(df.iloc[df_location]['Taiwan_Daily']+1)
#     Index_location = Index.index.get_loc(pd.Timestamp(special_date))
#     Index_location_value = Index['Adj Close'].iloc[Index_location]
#     ax1.scatter(df.index[df_location], df_location_value, facecolors='none', edgecolors='green', linewidths=4, s=500, zorder=4)
#     ax3.scatter(Index.index[Index_location], Index_location_value, facecolors='none', edgecolors='green', linewidths=4, s=500, zorder=4)

plt.tight_layout()
plt.savefig('Events/Covid_TAIEX_FED_BCI.png', dpi=360, transparent=True)
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# /var/folders/0j/0cgjnq7x6_xgggqt92c7300r0000gn/T/ipykernel_44304/2202635309.py:44: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_yticklabels([f'{int(x):,}' for x in ax1.get_yticks()], size=14, weight='bold', color='salmon')
# /var/folders/0j/0cgjnq7x6_xgggqt92c7300r0000gn/T/ipykernel_44304/2202635309.py:55: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_yticklabels([f'{int(x):,}' for x in ax2.get_yticks()], size=14, weight='bold', color='royalblue')
# /var/folders/0j/0cgjnq7x6_xgggqt92c7300r0000gn/T/ipykernel_44304/2202635309.py:74: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
# ...

# %%
plt.figure(figsize=(15, 4))
plt.plot(FRM)

start_period = '2020-01-30'
end_period = '2020-05-10'
plt.axvspan(pd.Timestamp(start_period), pd.Timestamp(end_period), color='grey', alpha=0.3)

start_period = '2021-05-01'
end_period = '2021-07-27'
plt.axvspan(pd.Timestamp(start_period), pd.Timestamp(end_period), color='grey', alpha=0.3)

start_period = '2022-02-24'
end_period = '2023-06-30'
plt.axvspan(pd.Timestamp(start_period), pd.Timestamp(end_period), color='grey', alpha=0.3)

start_period = '2022-11-01'
end_period = '2023-06-30'
plt.axvspan(pd.Timestamp(start_period), pd.Timestamp(end_period), color='grey', alpha=0.3)

special_date = '2020-01-16'
plt.axvline(pd.Timestamp(special_date), color='darkgreen', linewidth=2, alpha=1)

special_date = '2020-01-30'
plt.axvline(pd.Timestamp(special_date), color='darkgreen', linewidth=2, alpha=1)

special_date = '2021-06-25'
plt.axvline(pd.Timestamp(special_date), color='darkgreen', linewidth=2, alpha=1)

special_date = '2022-08-08'
plt.axvline(pd.Timestamp(special_date), color='darkgreen', linewidth=2, alpha=1)

special_date = '2020-01-16'
plt.text(pd.Timestamp(special_date)-pd.Timedelta(days=15), FRM.max(axis=0).iloc[0]+0.02, special_date+r'$\rightarrow$', fontsize=14, color='darkgreen', fontweight='bold', verticalalignment='bottom', horizontalalignment='right')

special_date = '2020-01-30'
plt.text(pd.Timestamp(special_date)+pd.Timedelta(days=15), FRM.max(axis=0).iloc[0]+0.02, r'$\leftarrow$'+special_date, fontsize=14, color='darkgreen', fontweight='bold', verticalalignment='bottom')

special_date = '2021-06-25'
plt.text(pd.Timestamp(special_date)+pd.Timedelta(days=15), FRM.max(axis=0).iloc[0]+0.02, r'$\leftarrow$'+special_date, fontsize=14, color='darkgreen', fontweight='bold', verticalalignment='bottom')

special_date = '2022-08-08'
plt.text(pd.Timestamp(special_date)+pd.Timedelta(days=15), FRM.max(axis=0).iloc[0]+0.02, r'$\leftarrow$'+special_date, fontsize=14, color='darkgreen', fontweight='bold', verticalalignment='bottom')

plt.ylabel(r'$\mathbf{FRM}^\mathbf{EF}$', fontsize=16)
plt.xticks(fontsize=14, fontweight='bold')
plt.yticks(fontsize=14, fontweight='bold')

plt.ylim(FRM.min(axis=0).iloc[0]-0.1, FRM.max(axis=0).iloc[0] + 0.1)
plt.savefig('FRM_Events.png', dpi=144, transparent=True)
plt.show()
